# %%
# --- Setup logger ---
import logging
import sys
import os
import json

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s",
    handlers=[
        logging.StreamHandler(sys.stdout)
    ]
)

logger = logging.getLogger(__name__)

# --- Standard libraries ---
sys.path.append(os.path.abspath(".."))

# --- Data manipulation ---
import numpy as np
import pandas as pd


# --- Custom modules and data ---
from setred_package import setred_scratch, simulated_data
from sklearn.model_selection import train_test_split, GridSearchCV

# --- Simulation parameters ---
m_stred = 100
n = 17000
K = 5
p = 5
kcenters = 5
label_rate = 0.01  # Label rate for semi-supervised learning

std_values = [1,1.5,2,3,4,5]
# Out:
# 2025-07-22 09:37:12,675 - INFO - NumExpr defaulting to 8 threads.

# %%
for std in std_values:
    logger.info(f"Running simulation with std={std}")
    # Save the generated data
    data_dir = os.path.join("../data/", f'std_{std}')
    os.makedirs(data_dir, exist_ok=True)
    
    # Generate data
    X_ori, y_ori, X, y, X_unlabel, y_unlabel, X_test, y_test = simulated_data.create_data(
        n=n,
        kcenters=kcenters,
        K=K,
        p=p,
        std=std,
        label_rate=label_rate,
        export_path= data_dir)
# Out:
# 2025-07-22 09:57:50,859 - INFO - Running simulation with std=1
# 2025-07-22 09:57:51,190 - INFO - Running simulation with std=1.5
# 2025-07-22 09:57:51,477 - INFO - Running simulation with std=2
# 2025-07-22 09:57:51,866 - INFO - Running simulation with std=3
# 2025-07-22 09:57:52,179 - INFO - Running simulation with std=4
# 2025-07-22 09:57:52,502 - INFO - Running simulation with std=5
